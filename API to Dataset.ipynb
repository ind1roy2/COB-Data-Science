# %%
# importing the necessary libraries
import requests
import pandas as pd

# %%
# fetching the url using requests
url = "https://data.binance.com/api/v3/ticker/24hr"
r = requests.get(url)

# %%
# validating the request
if r.status_code == 200:
    dataset = r.json()

# %%
# Converting to pandas dataframe
df = pd.DataFrame(dataset)

# %%
# Saving the file
df.to_csv("api_to_dataset.csv",index = False)

# %%
# first 5 rows of the created dataset
df.head()
# Out:
#     symbol  priceChange priceChangePercent weightedAvgPrice prevClosePrice  \
# 0   ETHBTC  -0.00051000             -0.843       0.06029981     0.06048000
# 1   LTCBTC  -0.00011000             -4.430       0.00243490     0.00248200
# 2   BNBBTC  -0.00003500             -0.439       0.00797767     0.00797900
# 3   NEOBTC  -0.00000440             -1.572       0.00028043     0.00028000
# 4  QTUMETH   0.00000800              0.591       0.00134276     0.00136100
#
#     lastPrice     lastQty    bidPrice        bidQty    askPrice  ...  \
# 0  0.05998000  1.13530000  0.05997000   53.29340000  0.05998000  ...
# 1  0.00237300  0.75300000  0.00237300   50.55800000  0.00237400  ...
# 2  0.00794400  1.44300000  0.00794400    7.17300000  0.00794500  ...
# 3  0.00027550  1.61000000  0.00027560  116.18000000  0.00027580  ...
# 4  0.00136100  1.70000000  0.00135500   95.20000000  0.00136000  ...
#
#     openPrice   highPrice    lowPrice          volume    quoteVolume  \
# 0  0.06049000  0.06070000  0.05997000  16685.14430000  1006.11110562
# 1  0.00248300  0.00249100  0.00236900  93489.93200000   227.63845252
# 2  0.00797900  0.00800700  0.00794100  15746.84200000   125.62306449
# 3  0.00027990  0.00028550  0.00027540  13814.59000000     3.87406614
# 4  0.00135300  0.00136100  0.00134100    720.80000000     0.96786110
#
#         openTime      closeTime    firstId     lastId  count
# 0  1695136783247  1695223183247  423142013  423172792  30780
# 1  1695136783071  1695223183071   93543482   93559104  15623
# 2  1695136783258  1695223183258  227208437  227231969  23533
# 3  1695136783268  1695223183268   45516908   45520942   4035
# 4  1695136760011  1695223160011    5402174    5402200     27
#
# [5 rows x 21 columns]
